# %%
import requests
import pandas as pd

# %%
url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd"

response = requests.get(url)
data = response.json()

# %%
type(data)
# Out:
# list

# %%
data[:5]
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 70151,
#   'market_cap': 1403762090921,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1403762582205,
#   'total_volume': 43312218928,
#   'high_24h': 70801,
#   'low_24h': 69265,
#   'price_change_24h': -336.939848515045,
#   'price_change_percentage_24h': -0.47801,
#   'market_cap_change_24h': -6829989644.39502,
#   'market_cap_change_percentage_24h': -0.48419,
#   'circulating_supply': 20001321.0,
#   'total_supply': 20001328.0,
#   'max_supply': 21000000.0,
#   'ath': 126080,
#   'ath_change_percentage': -44.35961,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 67.81,
#   'atl_change_percentage': 103354.32148,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-03-12T20:43:44.405Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...

# %%
df.shape
# Out:
# (100, 26)

# %%
df = pd.DataFrame(data)
df.head()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                100 non-null    object
#  1   symbol                            100 non-null    object
#  2   name                              100 non-null    object
#  3   image                             100 non-null    object
#  4   current_price                     100 non-null    float64
#  5   market_cap                        100 non-null    int64
#  6   market_cap_rank                   100 non-null    int64
#  7   fully_diluted_valuation           100 non-null    int64
#  8   total_volume                      100 non-null    float64
#  9   high_24h                          100 non-null    float64
#  10  low_24h                           100 non-null    float64
# ...

# %%
df = df[['name', 
         'symbol', 
         'current_price', 
         'market_cap', 
         'market_cap_rank', 
         'total_volume', 
         'price_change_percentage_24h', 
         'circulating_supply', 
         'ath',
         'atl'
        ]]

# %%
df.to_csv('updated_coungekco_dataset_for_analysis.csv', index = False)

# %%
#creating Columns

df['price_distance_from_ath'] = df['ath'] - df['current_price']

# %%
df['price_distance_from_atl'] = df['current_price'] - df['atl']

# %%
df['volatility_estimate'] = df['ath'] - df['atl']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         100 non-null    object
#  1   symbol                       100 non-null    object
#  2   current_price                100 non-null    float64
#  3   market_cap                   100 non-null    int64
#  4   market_cap_rank              100 non-null    int64
#  5   total_volume                 100 non-null    float64
#  6   price_change_percentage_24h  100 non-null    float64
#  7   circulating_supply           100 non-null    float64
#  8   ath                          100 non-null    float64
#  9   atl                          100 non-null    float64
#  10  price_distance_from_ath      100 non-null    float64
#  11  price_distance_from_atl      100 non-null    float64
#  12  volatility_estimate          100 non-null    float64
# ...

# %%
df.to_csv('crypto_market_data_v3.csv', index = False)

# %%
df.head()
# Out:
#        name symbol  current_price     market_cap  market_cap_rank  \
# 0   Bitcoin    btc   70151.000000  1403762090921                1
# 1  Ethereum    eth    2061.050000   248851846990                2
# 2    Tether   usdt       0.999982   183957375040                3
# 3       BNB    bnb     649.410000    88557237882                4
# 4       XRP    xrp       1.370000    84085622335                5
#
#    total_volume  price_change_percentage_24h  circulating_supply        ath  \
# 0  4.331222e+10                     -0.47801        2.000132e+07  126080.00
# 1  1.829355e+10                     -0.45289        1.206920e+08    4946.05
# 2  6.761791e+10                     -0.00676        1.839599e+11       1.32
# 3  8.628185e+08                     -0.47705        1.363582e+08    1369.99
# 4  1.930367e+09                     -1.32128        6.122783e+10       3.65
#
#          atl  price_distance_from_ath  price_distance_from_atl  \
# ...

# %%
#Top 10 Crypto

df.sort_values('market_cap',ascending = False).head(10)
# Out:
#            name      symbol  current_price     market_cap  market_cap_rank  \
# 0       Bitcoin         btc   70151.000000  1403762090921                1
# 1      Ethereum         eth    2061.050000   248851846990                2
# 2        Tether        usdt       0.999982   183957375040                3
# 3           BNB         bnb     649.410000    88557237882                4
# 4           XRP         xrp       1.370000    84085622335                5
# 5          USDC        usdc       0.999910    78799483013                6
# 6        Solana         sol      86.510000    49413952247                7
# 7          TRON         trx       0.288858    27367375686                8
# 8  Figure Heloc  figr_heloc       1.033000    16316480089                9
# 9      Dogecoin        doge       0.094235    14452507748               10
#
#    total_volume  price_change_percentage_24h  circulating_supply  \
# 0  4.331222e+10                     -0.47801        2.000132e+07
# ...

# %%
# Highest Trading Volume Coins

df.sort_values('total_volume', ascending = False).head(10)
# Out:
#         name symbol  current_price     market_cap  market_cap_rank  \
# 2     Tether   usdt       0.999982   183957375040                3
# 0    Bitcoin    btc   70151.000000  1403762090921                1
# 1   Ethereum    eth    2061.050000   248851846990                2
# 5       USDC   usdc       0.999910    78799483013                6
# 6     Solana    sol      86.510000    49413952247                7
# 4        XRP    xrp       1.370000    84085622335                5
# 21      USD1   usd1       0.999536     4613577374               22
# 9   Dogecoin   doge       0.094235    14452507748               10
# 3        BNB    bnb     649.410000    88557237882                4
# 28       Sui    sui       0.973521     3797276251               29
#
#     total_volume  price_change_percentage_24h  circulating_supply  \
# 2   6.761791e+10                     -0.00676        1.839599e+11
# 0   4.331222e+10                     -0.47801        2.000132e+07
# ...

# %%
# Biggest 24h Gainers

df.sort_values('price_change_percentage_24h', ascending = False).head(10)
# Out:
#              name  symbol  current_price  market_cap  market_cap_rank  \
# 38     Pi Network      pi       0.257211  2485247814               39
# 42      Bittensor     tao     213.470000  2049345952               43
# 72         Render  render       1.630000   844754355               73
# 84    XDC Network     xdc       0.033158   661126802               85
# 49  NEAR Protocol    near       1.330000  1716652438               50
# 35       MemeCore       m       1.470000  2563846960               36
# 14    Hyperliquid    hype      36.970000  8811215461               15
# 40         Mantle     mnt       0.713999  2342574266               41
# 60       Pump.fun    pump       0.002074  1222341293               61
# 45            Sky     sky       0.081411  1876543328               46
#
#     total_volume  price_change_percentage_24h  circulating_supply         ath  \
# 38   102783666.0                      9.13359        9.662292e+09    2.990000
# ...

# %%
# Coins closest to their All-Time High.

df.sort_values('price_distance_from_ath').head(5)
# Out:
#                                                  name symbol  current_price  \
# 41                                        Circle USYC   usyc          1.120
# 62  Superstate Short Duration U.S. Government Secu...   ustb         11.020
# 43  BlackRock USD Institutional Digital Liquidity ...  buidl          1.000
# 83               Janus Henderson Anemoy Treasury Fund  jtrsy          1.097
# 80                                               OUSG   ousg        114.570
#
#     market_cap  market_cap_rank  total_volume  price_change_percentage_24h  \
# 41  2310883935               42         99.62                     -0.00022
# 62  1091149443               63          0.00                      0.00961
# 43  1993947246               44          0.00                      0.00000
# 83   668598023               84          0.00                      0.00848
# 80   723382418               81          0.00                      0.00926
#
# ...

# %%
# Most volatile coins:

df.sort_values('volatility_estimate', ascending = False).head(10)
# Out:
#                  name symbol  current_price     market_cap  market_cap_rank  \
# 0             Bitcoin    btc       70151.00  1403762090921                1
# 1            Ethereum    eth        2061.05   248851846990                2
# 36           PAX Gold   paxg        5081.78     2540100684               37
# 33        Tether Gold   xaut        5048.23     2849515655               34
# 13       Bitcoin Cash    bch         454.04     9083202654               14
# 30              Zcash    zec         207.54     3445525725               31
# 3                 BNB    bnb         649.41    88557237882                4
# 16             Monero    xmr         351.59     6487946702               17
# 42          Bittensor    tao         213.47     2049345952               43
# 54  Internet Computer    icp           2.64     1451682191               55
#
#     total_volume  price_change_percentage_24h  circulating_supply        ath  \
# ...
